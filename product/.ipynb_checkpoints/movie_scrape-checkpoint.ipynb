# %%
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import time
import locale
import pandas as pd
import threading
import random
import urllib.parse

locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"}

# %%
df = pd.read_csv('../dataset.csv')
scraped = pd.read_csv('./product.csv')
df = df.rename(columns={'shopid': 'ShopId', 'item_name': 'ProductName', 'price': 'Price',  'stock': 'Stock','item_description': 'Description', 'category': 'Category'})[['ShopId', 'ProductName', 'Price', 'Stock', 'Description', 'Category']]
df = df.drop_duplicates(subset=['ProductName']).reset_index(drop=True)

# %%
def get_image_urls(i, link):
    options = webdriver.ChromeOptions()
    options.add_argument('headless')
    driver = webdriver.Chrome(options=options)
    driver.get(link)
    time.sleep(2)
    thumbnails = driver.find_elements(By.CSS_SELECTOR, 'img.Q4LuWd')

    image_urls = set()
    max_links_to_fetch = 5

    for img in thumbnails[0:3]:
        try:
            img.click()
            time.sleep(2)
        except Exception: continue
        actual_images = driver.find_elements(By.CSS_SELECTOR,'img.n3VNCb')
        for actual_image in actual_images:
            if actual_image.get_attribute('src') and 'http' in actual_image.get_attribute('src'):
                image_urls.add(actual_image.get_attribute('src'))
        if len(image_urls) >= max_links_to_fetch:
            break
    df.loc[i, 'image_urls'] = ','.join(image_urls)
    print(f'\rfinished scraping on product #{i}', end='')
    driver.quit()

# %%
prefix = 'https://www.google.com/search?q='
products = df.ProductName.apply(lambda x: urllib.parse.quote_plus(str(x))).values
suffix = '&hl=en-US&source=lnms&tbm=isch&sa=X&ved=2ahUKEwj7ldOXuuP9AhUlTmwGHdZhAeIQ_AUoAnoECAEQBA&biw=1277&bih=1363&dpr=1'

# for product in products:
#     print(get_image_urls(link, product, image_suffix))
i = 0
thread_list = list()
for product in products:
    link = f'{prefix}{product}{suffix}'
    t = threading.Thread(target=get_image_urls, args=(i, link), daemon=True)
    t.start()
    time.sleep(max(random.random(), 0.1))
    i += 1
    thread_list.append(t)

for thread in thread_list:
    thread.join()
print('Test completed!')
# Out:
# finished scraping on product #9587
# Exception in thread Thread-28824 (get_image_urls):
# Traceback (most recent call last):
#   File "c:\Users\vince\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1016, in _bootstrap_inner
# finished scraping on product #9580
#     self.run()
#   File "c:\Users\vince\AppData\Local\Programs\Python\Python310\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\vince\AppData\Local\Temp\ipykernel_27828\2677387352.py", line 5, in get_image_urls
#   File "c:\Users\vince\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 449, in get
#     self.execute(Command.GET, {"url": url})
#   File "c:\Users\vince\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 440, in execute
#     self.error_handler.check_response(response)
#   File "c:\Users\vince\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 245, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_CONNECTION_CLOSED
#   (Session info: headless chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x011BDCE3]
# 	(No symbol) [0x011539D1]
# 	(No symbol) [0x01064DA8]
# 	(No symbol) [0x010612F7]
# 	(No symbol) [0x01058835]
# 	(No symbol) [0x0105980A]
# 	(No symbol) [0x01058B10]
# 	(No symbol) [0x01057F65]
# 	(No symbol) [0x01057EFC]
# 	(No symbol) [0x01056BF6]
# 	(No symbol) [0x01057358]
# 	(No symbol) [0x01066542]
# 	(No symbol) [0x010BDB91]
# 	(No symbol) [0x010AAECC]
# 	(No symbol) [0x010BD57C]
# 	(No symbol) [0x010AACC6]
# 	(No symbol) [0x01086F68]
# 	(No symbol) [0x010880CD]
# 	GetHandleVerifier [0x01433832+2506274]
# 	GetHandleVerifier [0x01469794+2727300]
# 	GetHandleVerifier [0x0146E36C+2746716]
# 	GetHandleVerifier [0x01266690+617600]
# 	(No symbol) [0x0115C712]
# 	(No symbol) [0x01161FF8]
# 	(No symbol) [0x011620DB]
# 	(No symbol) [0x0116C63B]
# 	BaseThreadInitThunk [0x75A97D69+25]
# 	RtlInitializeExceptionChain [0x76FBBB9B+107]
# 	RtlClearBits [0x76FBBB1F+191]
# finished scraping on product #11932
# Exception in thread Thread-35905 (get_image_urls):
# Traceback (most recent call last):
#   File "c:\Users\vince\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1016, in _bootstrap_inner
# finished scraping on product #11942
#     self.run()
#   File "c:\Users\vince\AppData\Local\Programs\Python\Python310\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\vince\AppData\Local\Temp\ipykernel_27828\2677387352.py", line 5, in get_image_urls
#   File "c:\Users\vince\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 449, in get
#     self.execute(Command.GET, {"url": url})
#   File "c:\Users\vince\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 440, in execute
#     self.error_handler.check_response(response)
#   File "c:\Users\vince\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 245, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_CONNECTION_CLOSED
#   (Session info: headless chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x011BDCE3]
# 	(No symbol) [0x011539D1]
# 	(No symbol) [0x01064DA8]
# 	(No symbol) [0x010612F7]
# 	(No symbol) [0x01058835]
# 	(No symbol) [0x0105980A]
# 	(No symbol) [0x01058B10]
# 	(No symbol) [0x01057F65]
# 	(No symbol) [0x01057EFC]
# 	(No symbol) [0x01056BF6]
# 	(No symbol) [0x01057358]
# 	(No symbol) [0x01066542]
# 	(No symbol) [0x010BDB91]
# 	(No symbol) [0x010AAECC]
# 	(No symbol) [0x010BD57C]
# 	(No symbol) [0x010AACC6]
# 	(No symbol) [0x01086F68]
# 	(No symbol) [0x010880CD]
# 	GetHandleVerifier [0x01433832+2506274]
# 	GetHandleVerifier [0x01469794+2727300]
# 	GetHandleVerifier [0x0146E36C+2746716]
# 	GetHandleVerifier [0x01266690+617600]
# 	(No symbol) [0x0115C712]
# 	(No symbol) [0x01161FF8]
# 	(No symbol) [0x011620DB]
# 	(No symbol) [0x0116C63B]
# 	BaseThreadInitThunk [0x75A97D69+25]
# 	RtlInitializeExceptionChain [0x76FBBB9B+107]
# 	RtlClearBits [0x76FBBB1F+191]
# finished scraping on product #12020
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\SMU\Y2T2\ESD\syopi\product\movie_scrape.ipynb Cell 4 in 1
#      <a href='vscode-notebook-cell:/c%3A/SMU/Y2T2/ESD/syopi/product/movie_scrape.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a> link = f'{prefix}{product}{suffix}'
#      <a href='vscode-notebook-cell:/c%3A/SMU/Y2T2/ESD/syopi/product/movie_scrape.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> t = threading.Thread(target=get_image_urls, args=(i, link), daemon=True)
# ---> <a href='vscode-notebook-cell:/c%3A/SMU/Y2T2/ESD/syopi/product/movie_scrape.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a> t.start()
#      <a href='vscode-notebook-cell:/c%3A/SMU/Y2T2/ESD/syopi/product/movie_scrape.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a> time.sleep(max(random.random(), 0.1))
#      <a href='vscode-notebook-cell:/c%3A/SMU/Y2T2/ESD/syopi/product/movie_scrape.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a> i += 1
#
# File c:\Users\vince\AppData\Local\Programs\Python\Python310\lib\threading.py:935, in Thread.start(self)
#     933     _limbo[self] = self
#     934 try:
# --> 935     _start_new_thread(self._bootstrap, ())
#     936 except Exception:
#     937     with _active_limbo_lock:
#
# RuntimeError: can't start new thread
# finished scraping on product #12041finished scraping on product #12068

# %%
scraped
# Out:
#           ShopId                                        ProductName   Price  \
# 0         210000                              Golden mobile numbers  400.00
# 1         210000                              Golden Mobile Numbers    8.00
# 2         760000                       101% AUTHENTIC BASEBALL CAPS   35.00
# 3       11272000  Hada Labo Super Hydrating Perfect Gel Moisturi...   28.72
# 4       49082000  Women Lace Bra Bustier Crop Tops Soft Mesh Tri...    9.98
# ...          ...                                                ...     ...
# 118342  13744999       Cute Flower Sleeveless Mesh Baby Girls Dress    7.57
# 118343  13744999  Babies Beanie Hat Han Edition Cotton Letter Pr...    1.40
# 118344  13744999          Women Back Brest Dress Package Hips Dress    7.70
# 118345  13744999             Heart Alloy Pendant Necklace for women    0.60
# 118346  13744999            Women Mid Elastic Waist Straight Shorts    2.00
#
#         Stock                                        Description  \
# 0           1  Unregistered prepaid cards1) 93355333  selling...
# 1           1  Unregistered prepaid cards. Can port to post p...
# 2         300  PREORDER Takes about 23 weeks to arrive, will ...
# 3           8  Hada Labo Super Hydrating Perfect Gel Moisturi...
# 4         400  Material: Terylene Colors: BalckStyle: Sexy Br...
# ...       ...                                                ...
# 118342      0  Style: Cute Material: Cotton Fabric Type: Broa...
# 118343      0  Gender: Unisex Item Type: Baby Hat Material: C...
# 118344      0  Type: Dress Gender: Womens Size Type: Regular ...
# 118345      0  Gender: For Women Item Type: Pendant Necklaces...
# 118346      0  Style: Active Length: Mini Material: Nylon,Pol...
#
#                        Category  \
# 0              Mobile & Gadgets
# 1              Mobile & Gadgets
# 2               Women's Apparel
# 3               Health & Beauty
# 4               Women's Apparel
# ...                         ...
# 118342      Toys, Kids & Babies
# 118343      Toys, Kids & Babies
# 118344          Women's Apparel
# 118345  Jewellery & Accessories
# 118346          Women's Apparel
#
#                                                image_urls
# 0                                                     NaN
# 1       https://media.karousell.com/media/photos/produ...
# 2       https://media.karousell.com/media/photos/produ...
# 3       https://gphb01pdazurefileshare.blob.core.windo...
# 4                                                     NaN
# ...                                                   ...
# 118342                                                NaN
# 118343                                                NaN
# 118344                                                NaN
# 118345                                                NaN
# 118346                                                NaN
#
# [118347 rows x 7 columns]

# %%
df.to_csv('product.csv', index=False)
